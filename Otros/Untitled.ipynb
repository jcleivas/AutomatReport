# %%
import glob
import os
import pandas as pd

# %%
path=r"C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\{}\{}/"
#entries = os.listdir(path)

# %%
for r in ["Costo de Ventas","Gasto","Ingresos","Producción"]:
    for y in [2021,2022,2023]:
        filenames = glob.glob(os.path.join(path.format(y,r), "*.xlsx"), recursive=True)
        #print('File names:', filenames)
        for i in filenames:
            try:
                df=pd.read_excel(i)
                print(i)
            except:
                print("Bad file {} {}".format(y,i))
# Out:
# C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\2021\Costo de Ventas\1. Costo de Ventas Industria CEBE.xlsx
# C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\2021\Costo de Ventas\10. Costo de Ventas Industria CEBE.xlsx
# C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\2021\Costo de Ventas\11. Costo de Ventas Industria CEBE.xlsx
# C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\2021\Costo de Ventas\12. Costo de Ventas Industria CEBE.xlsx
# Bad file 2021 C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\2021\Costo de Ventas\2. Costo de Ventas Industria CEBE.xlsx
# Bad file 2021 C:\Users\jcleiva\OneDrive - Grupo-exito.com\Escritorio\Proyectos\Reportes Base\2021\Costo de Ventas\3. Costo de Ventas Industria CEBE.xlsx
# ...
